# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeGuandinango/jguandinangoExamen/blob/master/Kmeasn2023A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cabeceras de alg de kmeans

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# experto en pares y distancias y buscar el minimo
# matplot para graficas matematicas

# %%
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize']= (16,9)
plt.style.use('ggplot')

# %% [markdown]
# para importar el documento importar pandas

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('analisis.csv')

# %% [markdown]
# como revisar la cabecera

# %%
dataframe.head()

# %% [markdown]
# describe todos los datos

# %%
dataframe.describe()

# %% [markdown]
# agrupar y contabilizar

# %%
print(dataframe.groupby('categoria').size())
# Out:
# categoria
# 1    27
# 2    34
# 3     9
# 4    19
# 5     4
# 6     8
# 7    17
# 8    16
# 9     6
# dtype: int64

# %% [markdown]
# graficar el histograma

# %%
dataframe.drop(['categoria'],1).hist()
plt.show()
# Out:
# <ipython-input-9-20defdcd68fe>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dataframe.drop(['categoria'],1).hist()

# %%
sb.pairplot(dataframe.dropna(), hue='categoria',size=4, vars=['op','ex', 'ag'], kind='scatter')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X = np.array(dataframe[['op','ex','ag']])
y = np.array(dataframe['categoria'])
X.shape
# Out:
# (140, 3)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection= '3d')
colores= ['blue', 'red', 'green', 'blue', 'green', 'cian', 'yellow', 'orange', 'black', 'pink','brown', 'purple']
asignar=[]
for filas in y:
  asignar.append(colores[filas])
  ax.scatter( X[:,0], X[:,1], X[:,2], c=asignar, s=60)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ce3414bf1c0d> in <cell line: 5>()
#       5 for filas in y:
#       6   asignar.append(colores[filas])
# ----> 7   ax.scatter( X[:,0], X[:,1], X[:,2], c=asignar, s=60)
#       8   plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2273             zs = zs.copy()
#    2274
# -> 2275         patches = super().scatter(xs, ys, s=s, c=c, *args, **kwargs)
# ...

# %%
nc = range(1, 20)
kmeans =[KMeans(n_clusters=i) for i in nc]
kmeans

# %%
score = [kmeans[i].fit(X).score(X)] for i range
